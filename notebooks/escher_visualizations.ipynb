# %% [markdown]
# # Escher pathway visualizations

# %% [markdown]
# ## 1. Imports

# %%
# Automatic module reloading
# %load_ext autoreload
# %autoreload 2

# Packages
import os
import sys
import escher
from escher import Builder
import cobra as cb
import pandas as pd

# Add parent directory 
sys.path.append(os.path.abspath('..'))

# Paths
model_xml = os.path.join("../models", f"iML1515_GEM.xml")
data_path = os.path.join("../notebooks", "data", "exp_validation_results")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Standard Escher map - no flux info mapped

# %%
escher.list_available_maps()
# Out:
# [{'organism': 'Saccharomyces cerevisiae',
#   'map_name': 'iMM904.Central carbon metabolism'},
#  {'organism': 'Homo sapiens',
#   'map_name': 'RECON1.Inositol retinol metabolism'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Glycolysis TCA PPP'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Tryptophan metabolism'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Carbohydrate metabolism'},
#  {'organism': 'Homo sapiens',
#   'map_name': 'RECON1.Amino acid metabolism (partial)'},
#  {'organism': 'Escherichia coli', 'map_name': 'iJO1366.Nucleotide metabolism'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Fatty acid biosynthesis (saturated)'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Nucleotide and histidine biosynthesis'},
#  {'organism': 'Escherichia coli', 'map_name': 'e_coli_core.Core metabolism'},
#  {'organism': 'Escherichia coli', 'map_name': 'iJO1366.Central metabolism'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Fatty acid beta-oxidation'}]

# %%
# Model 
model = cb.io.read_sbml_model(model_xml)

# Builder
# Map could be changed to any of the above or create a new one
# iJO1366 is almost the same as iML1515
builder = Builder(map_name='iJO1366.Central metabolism', model=model)

# Configurations
builder .highlight_missing = True
builder.hide_secondary_metabolites = True
builder.reaction_label_style = {'font_size': 12}

# Display
builder
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/iJO1366.Central%20metabolism.json
# Builder(hide_secondary_metabolites=True, highlight_missing=True)

# %% [markdown]
# ## Regular model
#
# Reaction flux results from the iML1515 GEM constrained with kcat values using kinGEMs. No changes on model media.

# %%
# Process results
regular_path = os.path.join(data_path,
                        "W3110_MD121_M9+Glu_none", 
                        "df_FBA_regular_model.csv")

df_regular = pd.read_csv(regular_path)
df_reactions = df_regular[df_regular['Variable'] == 'flux']
flux_dict_regular = pd.Series(df_reactions['Value'].values, index=df_reactions['Index']).to_dict()
print(flux_dict_regular)

# %%
builder_regular = Builder(map_name='iJO1366.Central metabolism', model=model)

# Add fluxes to builder
builder_regular.reaction_data = flux_dict_regular

# Configurations
builder_regular .highlight_missing = True
builder_regular.hide_secondary_metabolites = True
builder_regular.reaction_label_style = {'font_size': 12}

# Display
builder_regular

# %% [markdown]
# ## COBRApy Modified

# %%
# Process results
cobrapy_path = os.path.join(data_path,
                        "W3110_MD121_M9+Glu_none", 
                        "cobrapy_FBA_v2.csv")

df_cobrapy = pd.read_csv(cobrapy_path)
flux_dict_cobrapy = pd.Series(df_cobrapy['flux'].values, index=df_cobrapy['rxn_id']).to_dict()
print(flux_dict_cobrapy)

# %%
builder_cobrapy = Builder(map_name='iJO1366.Central metabolism', model=model)

# Add fluxes to builder
builder_cobrapy.reaction_data = flux_dict_cobrapy

# Configurations
builder_cobrapy.show_colorbar = True
builder_cobrapy.highlight_missing = True
builder_cobrapy.hide_secondary_metabolites = True
builder_cobrapy.reaction_label_style = {'font_size': 12}

# Display
builder_cobrapy

# %% [markdown]
# ## kinGEMS Modified model
#
# Reaction flux results from the iML1515 GEM constrained with kcat values using kinGEMs AND changes on model media.

# %%
# Process results
modified_path = os.path.join(data_path, 
                        "W3110_MD121_M9+Glu_none", 
                        "df_FBA_modified_model_v2.csv")

df_modified = pd.read_csv(modified_path)
df_reactions_modified = df_modified[df_modified['Variable'] == 'flux']
flux_dict_modified = pd.Series(df_reactions_modified['Value'].values, index=df_reactions_modified['Index']).to_dict()
print(flux_dict_modified)

# %%
builder_modified = Builder(map_name='iJO1366.Central metabolism', model=model)

# Add fluxes to builder
builder_modified.reaction_data = flux_dict_modified

# Configurations
builder_modified.show_colorbar = True
builder_modified .highlight_missing = True
builder_modified.hide_secondary_metabolites = True
builder_modified.reaction_label_style = {'font_size': 12}

# Display
builder_modified

# %% [markdown]
# ## kinGEMS modified and tuned model
#
# Reaction flux results from the iML1515 GEM constrained with kcat values using kinGEMs AND changes on model media, AND kcat tuning

# %%
# Process results
modified_tuned_path = os.path.join(data_path, 
                        "W3110_MD121_M9+Glu_none", 
                        "df_FBA_modified_model_tuned_v2.csv")

df_modified_tuned = pd.read_csv(modified_tuned_path)
df_reactions_modified_tuned = df_modified_tuned[df_modified_tuned['Variable'] == 'flux']
flux_dict_modified_tuned = pd.Series(df_reactions_modified_tuned['Value'].values, index=df_reactions_modified_tuned['Index']).to_dict()
print(flux_dict_modified_tuned)
# Out:
# {'ALATA_D2': 0.0, 'SHCHD2': 0.0001079700164306, 'CPPPGO': 0.0001079700164306, 'GTHOr': 0.0, 'DHORD5': 0.0, 'GLYCTO2': 0.0, 'GLYCTO3': 0.0, 'GLYCTO4': 0.0, 'PFK_3': 0.0, 'TRPS2': 0.0, 'G3PD5': 0.0, 'EX_acgam_e': 0.0, 'EX_cellb_e': 0.0, 'EX_chol_e': 0.0, 'LEUTAi': 0.218133809293869, 'SHK3Dr': 0.1845265681257673, 'G5SD': 0.107028304852399, 'ALATA_L2': 0.0, 'MAN6PI': 0.0, 'APRAUR': 0.0002159400328614, 'DB4PS': 0.0004318800657228, 'RBFK': 0.0001079700164307, 'ACP1_FMN': 0.0, 'RBFSb': 0.0002159400328614, 'EX_pi_e': -0.467033747395247, 'EX_h_e': 14.39819135201524, 'DMATT': 0.0001345993926804, 'GRTT': 0.0001345993926804, 'UPP3S': 0.0002159400328613, 'UPPDC1': 0.0001079700164306, 'TMDPP': 0.0, 'EX_ade_e': 0.0, 'EX_4abut_e': 0.0, 'EX_ac_e': 9.949439822859722, 'EX_akg_e': 0.0, 'EX_ala__L_e': 0.0, 'EX_arg__L_e': 0.0, 'EX_asp__L_e': 0.0, 'EX_cytd_e': 0.0, 'EX_dcyt_e': 0.0, 'EX_fum_e': 0.0, 'EX_glu__L_e': 0.0, 'EX_gua_e': 0.0, 'HCO3E': 0.2544916229433289, 'IMPC': -0.2626779773729703, 'IMPD': 0.1177638168448546, 'ECOAH4': 0.1723065894500093, 'GLUTRS': 0.0017275202628909, 'TMPPP': 0.0001079700164306, 'URIK1': 0.0, 'URIK2': 0.0, 'CYTDK1': 0.0, 'CYTDK2': 0.0, 'XPPT': 0.0, 'HXPRT': 0.0, 'NDPK5': 0.0130808337843399, 'DHORTS': -0.1601611730277504, 'OMPDC': 0.1601611730277504, 'CS': 0.7747453891998213, 'ICDHyr': 0.7747453891998213, 'ACALD': -1.5683056058774578, 'ACS': 0.0, 'PPA': 1.682684624184548, 'PPCK': 0.0, 'ME1': 0.0, 'ALAR': 0.0201811938334699, 'ALATA_L': -0.2817116871753153, 'XYLK': 0.0, 'RBK': 0.0, 'GLYK': 0.067313253113566, 'PPM': -1.2705456413314409, 'ASPTA': -1.41756545926519, 'FBP': 0.0, 'GLGC': 0.0, 'PYK': 4.883757655500074, 'A5PISO': 0.0188400416114385, 'EX_met__L_e': 0.0, 'EX_metsox_S__L_e': 0.0, 'IPPMIb': -0.218133809293869, 'ACHBS': 0.1406655645900914, 'ACLS': 0.4233426876970788, 'PSCVT': 0.1845265681257673, 'ANS': 0.0275217024393246, 'ANPRT': 0.0275217024393246, 'CHORM': 0.1565729856207199, 'CHORS': 0.1845265681257673, 'IGPS': 0.0275217024393247, 'EX_crn_e': 0.0, 'EX_fe3_e': 0.0, 'EX_glcn_e': 0.0, 'EX_gln__L_e': 0.0, 'EX_glyc_e': 0.0, 'EX_man_e': 0.0, 'EX_mn2_e': -0.0003345617997919, 'EX_rib__D_e': 0.0, 'EX_sbt__D_e': 0.0, 'ECOAH6': 0.1346265062271321, 'ENO': 17.087778166957797, 'FBA': 8.636535427084379, 'MGSA': 0.0, 'PPS': 0.0, 'PGI': 7.173500872738352, 'PGK': -17.89325676137266, 'EDA': 0.0, 'PGL': 2.826499127261648, 'RPE': 1.5087828544020918, 'TALA': 0.8465467412474991, 'TKT1': 0.8465467412474991, 'G6PDA': 0.0, 'ALCD2x': -1.5683056058774576, 'ALDD2y': 0.0, 'RMI': 0.0, 'EX_ura_e': 0.0, 'EX_val__L_e': 0.0, 'EX_xan_e': 0.0, 'FMNAT': 0.0001079700164307, 'NADDP': 0.0, 'NMNAT': 0.0, 'HMPK1': 0.0, 'NDPK6': 0.0, 'NDPK8': 0.0126688047081851, 'PYNP2r': 0.0126688047081851, 'DURIPP': -0.0126688047081851, 'PTRCTA': 0.0, 'CYSDS': 0.0, 'TRPAS2': -0.0275217024393247, 'NDP3': 0.0, 'CDPPH': 0.0, 'NDP7': 0.0, 'EX_co2_e': 17.091535329861397, 'PMDPHT': 0.0002159400328614, 'ILETA': -0.1406655645900914, 'VALTA': -0.2048825475015309, 'ORPT': -0.1601611730277504, 'RBFSa': 0.0004318800657228, 'DHAD2': 0.1406655645900914, 'G1PP': 0.0, 'PFL': 13.876934831431551, 'FRD2': 0.0, 'FRD3': 0.0, 'POX': 0.0, 'PTAr': 9.667562549381184, 'ACKr': -9.667562549381184, 'EX_hxan_e': 0.0, 'EX_ile__L_e': 0.0, 'EX_lac__L_e': 0.0, 'EX_leu__L_e': 0.0, 'EX_no3_e': 0.0, 'EX_orn_e': 0.0, 'EX_pro__L_e': 0.0, 'EX_pyr_e': 0.0, 'EX_succ_e': 0.0, 'EX_thymd_e': 0.0, 'EX_tyr__L_e': 0.0, 'MOAT': 0.0094200208057192, 'UDCPDPS': 2.6629376249719062e-05, 'USHD': 0.0094200208057192, 'LPADSS': 0.0094200208057192, 'TDSK': 0.0094200208057192, 'EX_btn_e': 0.0, 'EX_ptrc_e': 0.0, 'EX_spmd_e': 0.0, 'EX_thym_e': 0.0, 'EX_xtsn_e': 0.0, 'NTPP1': 0.0, 'NTPP2': 0.0, 'NTPTP1': 0.0, 'NTPTP2': 0.0, 'IPMD': 0.218133809293869, 'AIRC3': -0.2168086346975881, 'ADSL2r': 0.2168086346975881, 'EX_fe2_e': -0.0077762620353956, 'PUNP5': 0.0, 'PUNP6': 0.0, 'PUNP7': 0.0, 'RNDR1': 0.0126688047081851, 'RNDR3': 0.0130808337843399, 'RNDR4': 0.0, 'TMDS': 0.0126688047081851, 'TMDK1': 0.0, 'PPCDC': 0.0003263309016787, 'FTHFD': 0. ...

# %%
builder_modified_tuned = Builder(map_name='iJO1366.Central metabolism', model=model)

# Add fluxes to builder
builder_modified_tuned.reaction_data = flux_dict_modified_tuned

# Configurations
builder_modified_tuned.show_colorbar = True
builder_modified_tuned .highlight_missing = True
builder_modified_tuned.hide_secondary_metabolites = True
builder_modified_tuned.reaction_label_style = {'font_size': 12}

# Display
builder_modified_tuned
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/iJO1366.Central%20metabolism.json
# Builder(hide_secondary_metabolites=True, highlight_missing=True, reaction_data={'ALATA_D2': 0.0, 'SHCHD2': 0.0…

# %% [markdown]
# #
