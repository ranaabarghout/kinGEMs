# %% [markdown]
# # Escher pathway visualizations

# %% [markdown]
# ## 1. Imports

# %%
# Automatic module reloading
# %load_ext autoreload
# %autoreload 2

# Packages
import os
import sys
import escher
from escher import Builder
import cobra as cb
import pandas as pd

# Add parent directory 
sys.path.append(os.path.abspath('..'))

# Paths
model_xml = os.path.join("../models", f"iML1515_GEM.xml")
data_path = os.path.join("../notebooks", "data", "exp_validation_results")

# %% [markdown]
# ## Standard Escher map - no flux info mapped

# %%
escher.list_available_maps()
# Out:
# [{'organism': 'Saccharomyces cerevisiae',
#   'map_name': 'iMM904.Central carbon metabolism'},
#  {'organism': 'Homo sapiens',
#   'map_name': 'RECON1.Inositol retinol metabolism'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Glycolysis TCA PPP'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Tryptophan metabolism'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Carbohydrate metabolism'},
#  {'organism': 'Homo sapiens',
#   'map_name': 'RECON1.Amino acid metabolism (partial)'},
#  {'organism': 'Escherichia coli', 'map_name': 'iJO1366.Nucleotide metabolism'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Fatty acid biosynthesis (saturated)'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Nucleotide and histidine biosynthesis'},
#  {'organism': 'Escherichia coli', 'map_name': 'e_coli_core.Core metabolism'},
#  {'organism': 'Escherichia coli', 'map_name': 'iJO1366.Central metabolism'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Fatty acid beta-oxidation'}]

# %%
# Model 
model = cb.io.read_sbml_model(model_xml)

# Builder
# Map could be changed to any of the above or create a new one
# iJO1366 is almost the same as iML1515
builder = Builder(map_name='iJO1366.Central metabolism', model=model)

# Configurations
builder .highlight_missing = True
builder.hide_secondary_metabolites = True
builder.reaction_label_style = {'font_size': 12}

# Display
builder
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/iJO1366.Central%20metabolism.json
# Builder(hide_secondary_metabolites=True, highlight_missing=True)

# %% [markdown]
# ## Regular model
#
# Reaction flux results from the iML1515 GEM constrained with kcat values using kinGEMs. No changes on model media.

# %%
# Process results
regular_path = os.path.join(data_path,
                        "W3110_MD121_M9+Glu_none", 
                        "df_FBA_regular_model.csv")

df_regular = pd.read_csv(regular_path)
df_reactions = df_regular[df_regular['Variable'] == 'flux']
df_reactions = df_reactions[df_reactions['Value'] != 0] # drop 0 value fluxes
flux_dict_regular = pd.Series(df_reactions['Value'].values, index=df_reactions['Index']).to_dict()
print(flux_dict_regular)
# Out:
# {'SHCHD2': 2.91713561865065e-05, 'CPPPGO': 2.91713561865065e-05, 'LEUTAi': 0.0589354272379505, 'SHK3Dr': 0.0498554174820356, 'G5SD': 0.0289169244027274, 'APRAUR': 5.83427123730504e-05, 'DB4PS': 0.0001166854247461, 'RBFK': 2.91713561865439e-05, 'RBFSb': 5.83427123730504e-05, 'EX_pi_e': -0.126183252035048, 'EX_h_e': 18.9608322996116, 'DMATT': 3.6366085290801e
-0.114378794596178, 'KARA2': 0.0380050445808138, 'ACCOAC': 0.010181195749199, 'NADK': 5.84735295836627e-05, 'HACD6': 0.0363734108336757, 'ECOAH1': 0.0465538217030144, 'ECOAH2': 0.0465538217030144, 'ECOAH3': 0.0465538217026733, 'DXPS': 0.0003708555820123, 'CDPMEK': 0.0003125128696392, 'MECDPS': 0.0003125128696392, 'GLYCL': 0.0070911904112618, 'PPC': 0.387236410434233, 'GTPCII2': 5.83427123730504e-05, 'SADT2': 0.0323739263318132, 'NNDPR': 0.000297992602754, 'HACD4': 0.0465538217029007, 'HACD7': 0.0363734108331073, 'SDPDS': 0.0485250466636509, 'ADK1': 9.65477644285784e-05, 'OCTDPS': 2.91713561865065e-05, 'AACPS3': 0.0166954342929165, 'AACPS4': 0.0196779765400233, 'UDCPDP': 0.0036350387700028, 'CYTK1': 0.0236775918571084, 'GK1': 0.0318174467381596, 'HACD1': 0.0465538217031281, 'HACD2': 0.0465538217030144, 'UAPGR': 0.0036350387700028, 'TRPS3': 0.0074358179359174, 'FADRx': 0.285943389123947, 'NDPK2': -9.02316018334011, 'NDPK3': 0.0236775918572221, 'NDPK4': 0.0034228596679213, 'FCLT': 2.91713561865065e-05, 'HBZOPT': 2.91713561865065e-05, 'PNTK': 8.81681362706339e-05, 'DPCOAK': 8.816813 ...

# %%
builder_regular = Builder(map_name='iJO1366.Central metabolism', model=model)

# Add fluxes to builder
builder_regular.reaction_data = flux_dict_regular

# Configurations
builder_regular .highlight_missing = True
builder_regular.hide_secondary_metabolites = True
builder_regular.reaction_label_style = {'font_size': 12}

# Display
builder_regular
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/iJO1366.Central%20metabolism.json
# Builder(hide_secondary_metabolites=True, highlight_missing=True, reaction_data={'SHCHD2': 2.91713561865065e-05…

# %% [markdown]
# ## COBRApy Modified

# %%
# Process results
cobrapy_path = os.path.join(data_path,
                        "W3110_MD121_M9+Glu_none", 
                        "df_FBA_cobrapy.csv")

df_cobrapy = pd.read_csv(cobrapy_path)
df_cobrapy = df_cobrapy[df_cobrapy['Value'] != 0] # drop 0 value fluxes
flux_dict_cobrapy = pd.Series(df_cobrapy['Value'].values, index=df_cobrapy['Index']).to_dict()
print(flux_dict_cobrapy)
# Out:
# {'SHCHD2': 0.0001079700164306, 'CPPPGO': 0.0001079700164306, 'GLYCTO2': 0.0002159400328613, 'PFK_3': 0.1845265681257758, 'LEUTAi': 0.2181338092938791, 'SHK3Dr': 0.1845265681257758, 'G5SD': 0.107028304852404, 'APRAUR': 0.0002159400328613, 'DB4PS': 0.0004318800657227, 'RBFK': 0.0001079700164306, 'RBFSb': 0.0002159400328613, 'EX_pi_e': -0.4670337473951291, 'EX_h_e': 18.940043339415205, 'DMATT': 0.0001345993926804, 'GRTT': 0.0001345993926804, 'UPP3S': 0.0002159400328613, 'UPPDC1': 0.0001079700164306, 'HCO3E': 1.5575841720976735, 'IMPC': -0.2626779773729353, 'IMPD': 0.11776381684486, 'GLUTRS': 0.001727520262891, 'TMPPP': 0.0001079700164306, 
1': -0.4233426876970978, 'KARA2': 0.1406655645900979, 'ACCOAC': 1.340775537400123, 'NADK': 0.0002164242033367, 'HACD6': -7.705405780413619e-34, 'DXPS': 0.0013726233030538, 'CDPMEK': 0.0011566832701924, 'MECDPS': 0.0011566832701924, 'PPC': 4.255496003638998, 'GTPCII2': 0.0002159400328613, 'SADT2': 0.1198234780551567, 'ALCD19': 0.0673132531135691, 'GLXCL': 0.0001079700164306, 'KAS14': 0.1723065894500173, 'NNDPR': 0.0011029403472137, 'HACD7': -1.5475519438029228e-17, 'SDPDS': 0.1796025543719636, 'ADK1': 0.6463414419465143, 'OCTDPS': 0.0001079700164306, 'CAT': 5.398500821534484e-05, 'UDCPDP': 0.0134541292223139, 'CYTK1': 0.0876363088968793, 'GK1': 0.11776381684486, 'UAPGR': 0.0134541292223139, 'NDPK7': 0.0130808337843405, 'TRPS3': 0.0275217024393259, 'NDPK2': 0.1932406683756394, 'N ...

# %%
builder_cobrapy = Builder(map_name='iJO1366.Central metabolism', model=model)

# Add fluxes to builder
builder_cobrapy.reaction_data = flux_dict_cobrapy

# Configurations
builder_cobrapy.show_colorbar = True
builder_cobrapy.highlight_missing = True
builder_cobrapy.hide_secondary_metabolites = True
builder_cobrapy.reaction_label_style = {'font_size': 12}

# Display
builder_cobrapy
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/iJO1366.Central%20metabolism.json
# Builder(hide_secondary_metabolites=True, highlight_missing=True, reaction_data={'SHCHD2': 0.0001079700164306, …

# %% [markdown]
# ## kinGEMS Modified model
#
# Reaction flux results from the iML1515 GEM constrained with kcat values using kinGEMs AND changes on model media.

# %%
# Process results
modified_path = os.path.join(data_path, 
                        "W3110_MD121_M9+Glu_none", 
                        "df_FBA_modified_model.csv")

df_modified = pd.read_csv(modified_path)
df_reactions_modified = df_modified[df_modified['Variable'] == 'flux']
df_reactions_modified = df_reactions_modified[df_reactions_modified['Value'] != 0] # drop 0 value fluxes
flux_dict_modified = pd.Series(df_reactions_modified['Value'].values, index=df_reactions_modified['Index']).to_dict()
print(flux_dict_modified)
# Out:
# {'SHCHD2': 2.91713560819895e-05, 'CPPPGO': 2.91713560819895e-05, 'LEUTAi': 0.0589354270267929, 'SHK3Dr': 0.0498554173033199, 'G5SD': 0.0289169242991219, 'APRAUR': 5.83427121639473e-05, 'DB4PS': 0.0001166854243278, 'RBFK': 2.91713560819578e-05, 'RBFSb': 5.83427121639473e-05, 'EX_pi_e': -0.126183251592124, 'EX_h_e': 18.9608323033262, 'DMATT': 3.63660851605063e-05, 'GRTT': 3.63660851605063e-05, 'UPP3S': 5.8342712163979e-05, 'UPPDC1': 2.91713560819895e-05, 'EX_ac_e': 1.77194526835337, 'HCO3E': 0.0687585868548695, 'IMPC': -0.0709703773868569, 'IMPD': 0.0318174466239141, 'ECOAH4': 0.0465538215365768, 'GLUTRS': 0.0004667416973118, 'TMPPP': 2.91713560819895e-05, 'DHORTS': -0.0432723710091523, 'OMPDC': 0.0432723710090845, 'CS': 0.14064936631716, 'ICDHyr': 0.140649366317234, '
679, 'NNDPR': 0.0002979925971066, 'HACD4': 0.0465538215365768, 'HACD7': 0.0363734107029359, 'SDPDS': 0.0485250464897821, 'ADK1': 9.654776329171e-05, 'OCTDPS': 2.91713560819492e-05, 'AACPS3': 0.016695434233328, 'AACPS4': 0.0196779764696099, 'UDCPDP': 0.003635038756979, 'CYTK1': 0.0236775917736622, 'GK1': 0.0318174466234495, 'HACD1': 0.0465538215369179, 'HACD2': 0.0465538215365768, 'UAPGR': 0.003635038756979, 'TRPS3': 0.0074358179092759, 'FADRx': 0.285943388105806, 'NDPK2': -9.02316018684598, 'NDPK3': 0.0236775917736622, 'NDPK4': 0.0034228596557568, 'FCLT': 2.91713560819895e-05, 'HBZOPT': 2.91713560819492e-05, 'PNTK': 8.81681371830418e-05, 'DPCOAK': 8.81681 ...

# %%
builder_modified = Builder(map_name='iJO1366.Central metabolism', model=model)

# Add fluxes to builder
builder_modified.reaction_data = flux_dict_modified

# Configurations
builder_modified.show_colorbar = True
builder_modified .highlight_missing = True
builder_modified.hide_secondary_metabolites = True
builder_modified.reaction_label_style = {'font_size': 12}

# Display
builder_modified
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/iJO1366.Central%20metabolism.json
# Builder(hide_secondary_metabolites=True, highlight_missing=True, reaction_data={'SHCHD2': 2.91713560819895e-05…

# %% [markdown]
# ## kinGEMS modified and tuned model
#
# Reaction flux results from the iML1515 GEM constrained with kcat values using kinGEMs AND changes on model media, AND kcat tuning

# %%
# Process results
modified_tuned_path = os.path.join(data_path, 
                        "W3110_MD121_M9+Glu_none", 
                        "df_FBA_modified_model_tuned.csv")

df_modified_tuned = pd.read_csv(modified_tuned_path)
df_reactions_modified_tuned = df_modified_tuned[df_modified_tuned['Variable'] == 'flux']
df_reactions_modified_tuned = df_reactions_modified_tuned[df_reactions_modified_tuned['Value'] != 0] # drop 0 value fluxes
flux_dict_modified_tuned = pd.Series(df_reactions_modified_tuned['Value'].values, index=df_reactions_modified_tuned['Index']).to_dict()
print(flux_dict_modified_tuned)
# Out:
# {'SHCHD2': 7.83314908924766e-05, 'CPPPGO': 7.83314908924766e-05, 'DHORD5': 0.116161385845627, 'LEUTAi': 0.158254551225464, 'SHK3Dr': 0.13387273308399, 'G5SD': 0.0776482857365974, 'APRAUR': 0.0001566629817849, 'DB4PS': 0.0003133259635699, 'RBFK': 7.83314908924797e-05, 'RBFSb': 0.0001566629817849, 'EX_pi_e': -0.338829713494306, 'EX_h_e': 17.9416548444913, 'DMATT': 9.76509168973475e-05, 'GRTT': 9.76509168973475e-05, 'UPP3S': 0.0001566629817849, 'UPPDC1': 7.83314908924766e-05, 'EX_ac_e': 13.7425303540736, 'HCO3E': 0.184631890450873, 'IMPC': -0.190571033266679, 'IMPD': 0.0854368245157215, 'ECOAH4': 0.125007224118917, 'GLUTRS': 0.0012533038542796, 'TMPPP': 7.83314908924766e-05, 'DHORTS': -0.116195809550277, 'OMPDC': 0.116195809550282, 'CS': 0.377674405181539, 'ICDHyr': 0.377674405181551, 'PPA': 1.22996704146285, 'ALAR
05, 'AACPS3': 0.0448309036754484, 'AACPS4': 0.0528396839101949, 'UDCPDP': 0.0097608765422427, 'CYTK1': 0.0635795284584901, 'GK1': 0.0854368245155683, 'HACD1': 0.125007224119258, 'HACD2': 0.125007224119258, 'UAPGR': 0.0097608765422427, 'TRPS3': 0.0199668024073247, 'FADRx': 0.980557620627675, 'NDPK2': 0.149385880902059, 'NDPK3': -7.3156258133439, 'NDPK4': 0.0091911291062842, 'FCLT': 7.83314908924766e-05, 'HBZOPT': 7.83314908924766e-05, 'PNTK': 0.0002367507851571, 'DPCOAK': 0.0002367507851571, 'KDOPS': 0.0136683182673007, 'KDOPP': 0.0136683182673007, 'DTMPK': 0.0091911291060569, 'NDPK1': 0 ...

# %%
builder_modified_tuned = Builder(map_name='iJO1366.Central metabolism', model=model)

# Add fluxes to builder
builder_modified_tuned.reaction_data = flux_dict_modified_tuned

# Configurations
builder_modified_tuned.show_colorbar = True
builder_modified_tuned .highlight_missing = True
builder_modified_tuned.hide_secondary_metabolites = True
builder_modified_tuned.reaction_label_style = {'font_size': 12}

# Display
builder_modified_tuned
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/iJO1366.Central%20metabolism.json
# Builder(hide_secondary_metabolites=True, highlight_missing=True, reaction_data={'SHCHD2': 7.83314908924766e-05…

# %% [markdown]
# ## Experimental fluxes

# %%
# Process results
experimental_path = os.path.join("../data",
                        "experimental", 
                        "fluxes_W3110_MD121_M9+Glu_none.csv")

df_experimental = pd.read_csv(experimental_path)
flux_dict_exp = pd.Series(df_experimental['exp_flux'].values, index=df_experimental['rxn_id']).to_dict()
print(flux_dict_exp)
# Out:
# {'SHK3Dr': 0.13, 'G5SD': 0.16, 'CS': 2.13, 'ICDHyr': 2.02, 'PPCK': 0.03, 'ME1': 0.03, 'ALATA_L': -0.37, 'ASPTA': -1.59, 'PYK': 3.02, 'EX_co2_e': 16.22, 'ILETA': -0.21, 'VALTA': -0.3, 'IPPMIb': -0.32, 'ACHBS': 0.21, 'DHAD2': 0.21, 'ACLS': 0.3, 'TRPS2': 0.04, 'PSCVT': 0.13, 'ANS': 0.04, 'ANPRT': 0.04, 'CHORM': 0.13, 'PTAr': 6.609999999999999, 'CHORS': 0.13, 'IGPS': 0.04, 'ACKr': -6.609999999999999, 'LEUTAi': 0.32, 'EX_ac_e': 6.99, 'ENO': 15.93, 'FBA': 8.34, 'PGI': 7.3, 'PGK': -0.8099999999999999, 'EDA': 0.1, 'RPE': 2.67, 'DHQTi': 0.13, 'IPMD': 0.32, 'TALA': -0.6799999999999999, 'TKT1': 1.09, 'EX_glc__D_e': -10.0, 'DHAD1': 0.3, 'IPPMIa': -0.32, 'EDD': 0.1, 'MDH': 1.64, 'FUM': 1.59, 'THRD': 0.21, 'KARA1': -0.3, 'KARA2': 0.21, 'RBP4E': 1.09, 'ARGSS': 0.21, 'ICL': 0.11, 'PPC': 2.3600000000000003, 'SADT2': 0.1699999999999999, 'GHMT2r': 0.35, 'TRPS3': 0.04, 'ASNS2': 0.1699999999999999, 'DAPE': 0.24, 'DHDPRy': 0.24, 'HSK': 0.61, 'SDPTA': -0.24, 'THRS': 0.61, 'HSST': 0.11, 'PPNDH': 0.13, 'DDPA': 0.13, 'MALS': 0.11, 'NADTRHD': 6.2, 'P5CR': 0.16, 'G5SADs': 0.16, 'AKGDH': 0.85, 'ATPPRT': 0.0699999999999999, 'HISTD': 0.0699999999999999, 'DHDPS': 0.24, 'IGPDH': 0.0699999999999999, 'PRMICI': 0.0699999999999999, 'SERAT': 0.1699999999999999, 'CYSS': 0.1699999999999999, 'PAPSR': 0.1699999999999999, 'ASPK': 0.61, 'ASAD': -0.61, 'DAPDC': 0.24, 'PHETA1': -0.13, 'PPND': 0.1, 'TRPS1': 0.04, 'PRAMPC': 0.0699999999999999, 'SULR': 0.1699999999999999, 'PSERT': 0.73, 'GAPD': 17.130000000000003, 'GND': 2.45, 'G6PDH2r': 2.55, 'ARGSL': 0.21, 'GLU5K': 0.16, 'IPPS': 0.32, 'NADH5': 1.3199999999999998, 'FTHFLi': 0.0699999999999999, 'ACtex': -6.99, 'CHRPL': 0.13, 'PSP_L': 0.73, 'ADSK': 0.1699999999999999, 'HSDy': -0.61, 'CYSTL': 0.11, 'SHSL1': 0.11, 'SULabcpp': 0.1699999999999999, 'O2tpp': 14.49, 'TKT2': -0.41, 'ATPS4rpp': 27.660000000000004, 'ACt4pp': 6.99, 'CO2tpp': -16.22, 'O2tex': 14.49, 'ACt2rpp': -6.99, 'METS': 0.11, 'MTHFC': 0.11, 'MTHFD': 0.0699999999999999, 'SO4tex': 0.1699999999999999, 'NH4tpp': 5.23, 'NH4tex': 5.23, 'CO2tex': -16.22, 'GLUDy': -5.0200000000000005, 'GLCptspp': 10.0, 'HSTPT': 0.0699999999999999, 'THDPS': 0.24, 'PRAIi': 0.04, 'TYRTA': -0.1, 'SHKK': 0.13, 'EX_so4_e': -0.1699999999999999, 'OMCDC': 0.32, 'PDH': 11.2, 'MTHFR2': 0.11, 'EX_nh4_e': -5.23, 'GLNS': 0.51, 'SUCOAS': -0.85, 'HISTP': 0.0699999999999999, 'DHQS': 0.13, 'PGCD': 0.73, 'PFK': 8.34, 'PGM': -15.93, 'CYTBO3_4pp': 27.660000000000004, 'TPI': 8.34, 'RPI': -1.36, 'SO4t2pp': 0.1699999999999999, 'ACONTb': 1.21, 'SUCDi': 1.3199999999999998, 'EX_o2_e': -14.49, 'ACONTa': 1.21, 'BIOMASS_Ec_iML1515_core_75p37M': 0.75, 'BIOMASS_Ec_iML1515_WT_75p37M': 0.75}

# %%
builder_experimental = Builder(map_name='iJO1366.Central metabolism', model=model)

# Add fluxes to builder
builder_experimental.reaction_data = flux_dict_exp

# Configurations
builder_experimental.show_colorbar = True
builder_experimental.highlight_missing = True
builder_experimental.hide_secondary_metabolites = True
builder_experimental.reaction_label_style = {'font_size': 12}

# Display
builder_experimental
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/iJO1366.Central%20metabolism.json
# Builder(hide_secondary_metabolites=True, highlight_missing=True, reaction_data={'SHK3Dr': 0.13, 'G5SD': 0.16, …
